# %% [markdown]
# # EDA - Singapore CPI Forecasting

# %% [markdown]
# This is a simple CPI projection for the purpose of adding ML element in the capstone project.

# %%
DATASET_ID = "d_dcb352661fb449c4a4c0ab23aa8d6399"

# %%
import json
import requests

s = requests.Session()
base_url = "https://api-production.data.gov.sg"
url = base_url + f"/v2/public/api/datasets/{DATASET_ID}/metadata"
print(url)
response = s.get(url)
data = response.json()['data']
columnMetadata = data.pop('columnMetadata', None)

print("Dataset Metadata:")
print(json.dumps(data, indent=2))

print("\nColumns:\n", list(columnMetadata['map'].values()))
# Out:
# https://api-production.data.gov.sg/v2/public/api/datasets/d_dcb352661fb449c4a4c0ab23aa8d6399/metadata
# Dataset Metadata:
# {
#   "datasetId": "d_dcb352661fb449c4a4c0ab23aa8d6399",
#   "createdAt": "2023-02-17T16:25:41+08:00",
#   "name": "Consumer Price Index (CPI), 2019 As Base Year, Annual",
#   "collectionIds": [
#     "779"
#   ],
#   "description": "Source: SINGAPORE DEPARTMENT OF STATISTICS\r\n\r\nData Last Updated: 23/01/2025\r\n\r\nUpdate Frequency: Annual\r\n\r\nFootnotes: The weighting pattern of the Consumer Price Index (CPI) was derived from the expenditure values collected from the 2017/18 Household Expenditure Survey (HES) and updated to 2019 values by taking into account price changes between 2017/18 and 2019.  For more information on the CPI rebasing, refer to the Information Paper 'Rebasing of the Consumer Price Index (2019 as Base Year)' (https://www.singstat.gov.sg/-/media/files/publications/economy/ip-e48.pdf).\r\n\r\nAdapted from: https://tablebuilder.singstat.gov.sg/table/TS/M212931",
#   "format": "CSV",
#   "lastUpdatedAt": "2025-02-01T23:00:56+08:00",
#   "managedBy": "Singapore Department of Statistics",
#   "coverageStart": "1961-01-01T08:00:00+08:00",
#   "coverageEnd": "2024-12-31T08:00:00+08:00",
#   "contactEmails": [
#     "feedback@data.gov.sg"
#   ],
#   "datasetSize": 65445
# }
#
# Columns:
#  ['DataSeries', '2024', '2023', '2022', '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961']

# %%
import time
import pandas as pd

def download_file(DATASET_ID):
  # initiate download
  initiate_download_response = s.get(
      f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/initiate-download",
      headers={"Content-Type":"application/json"},
      json={}
  )
  print(initiate_download_response.json()['data']['message'])

  # poll download
  MAX_POLLS = 5
  for i in range(MAX_POLLS):
    poll_download_response = s.get(
        f"https://api-open.data.gov.sg/v1/public/api/datasets/{DATASET_ID}/poll-download",
        headers={"Content-Type":"application/json"},
        json={}
    )
    print("Poll download response:", poll_download_response.json())
    if "url" in poll_download_response.json()['data']:
      print(poll_download_response.json()['data']['url'])
      DOWNLOAD_URL = poll_download_response.json()['data']['url']
      df = pd.read_csv(DOWNLOAD_URL)

      display(df.head())
      print("\nDataframe loaded!")
      return df
    if i == MAX_POLLS - 1:
# 2      na      na      na      na      na      na      na
# 3      na      na      na      na      na      na      na
# 4      na      na      na      na      na      na      na
#
# [5 rows x 65 columns]
# Dataframe loaded!

# %%
df
# Out:
#                                             DataSeries     2024     2023  \
# 0                                            All Items  116.283  113.595
# 1                                                 Food  118.384  115.122
# 2                      Food Excl Food Serving Services  117.192  115.750
# 3                                      Bread & Cereals  118.054  113.923
# 4                                                 Rice  103.613  101.378
# ..                                                 ...      ...      ...
# 147                             Other Personal Effects   97.953   97.939
# 148                                    Social Services   94.506   93.845
# 149                       Other Miscellaneous Services   96.500   95.154
# 150  All Items Less Imputed Rentals On Owner-Occupi...  116.521  113.973
# 151                       All Items Less Accommodation  116.845  114.334
#
#         2022     2021     2020   2019     2018     2017    2016  ...    1970  \
# 0    108.370  102.119   99.818  100.0   99.438   99.004  98.436  ...  27.079
# 1    108.813  103.326  101.862  100.0   98.498   97.104  95.759  ...  24.129
# 2    110.088  104.546  102.898  100.0    98.87   97.608  96.366  ...      na
# 3    106.683  102.592  101.930  100.0   98.501   97.127  96.535  ...      na
# 4     98.426   99.802  101.754  100.0   96.202   94.898  95.374  ...      na
# ..       ...      ...      ...    ...      ...      ...     ...  ...     ...
# 147   98.728   96.071   93.133  100.0  100.711  100.984  98.183  ...      na
# 148   94.962   95.309   97.078  100.0   99.774   97.994  97.872  ...      na
# 149   95.772  100.020  100.039  100.0  100.065  100.033  97.944  ...      na
# 150  108.705  102.128   99.683  100.0   99.098    97.85  96.202  ...      na
# 151  108.992  102.197   99.657  100.0   99.067   97.742  95.971  ...      na
#
#        1969    1968    1967    1966    1965    1964    1963    1962    1961
# 0    26.989  27.058  26.874  26.028  25.513  25.448  25.033  24.513  24.401
# 1     24.25  24.725   24.68  23.565  22.926  23.034  22.468  21.674  21.522
# 2        na      na      na      na      na      na      na      na      na
# 3        na      na      na      na      na      na      na      na      na
# 4        na      na      na      na      na      na      na      na      na
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 147      na      na      na      na      na      na      na      na      na
# 148      na      na      na      na      na      na      na      na      na
# 149      na      na      na      na      na      na      na      na      na
# 150      na      na      na      na      na      na      na      na      na
# 151      na      na      na      na      na      na      na      na      na
#
# [152 rows x 65 columns]

# %%
df.T
# Out:
#                   0         1                                    2    \
# DataSeries  All Items      Food      Food Excl Food Serving Services
# 2024          116.283   118.384                              117.192
# 2023          113.595   115.122                               115.75
# 2022           108.37   108.813                              110.088
# 2021          102.119   103.326                              104.546
# ...               ...       ...                                  ...
# 1965           25.513    22.926                                   na
# 1964           25.448    23.034                                   na
# 1963           25.033    22.468                                   na
# 1962           24.513    21.674                                   na
# 1961           24.401    21.522                                   na
#
#                                 3                 4                  5    \
# DataSeries          Bread & Cereals              Rice              Flour
# 2024                        118.054           103.613            108.224
# 2023                        113.923           101.378            108.495
# 2022                        106.683            98.426             97.892
# 2021                        102.592            99.802             95.925
# ...                             ...               ...                ...
# 1965                             na                na                 na
# 1964                             na                na                 na
# 1963                             na                na                 na
# 1962                             na                na                 na
# 1961                             na                na                 na
#
#                           6                            7    \
# DataSeries              Bread              Noodles & Pasta
# 2024                  121.262                      118.587
# 2023                  116.069                      117.322
# 2022                  107.311                      110.189
# 2021                  102.135                      103.317
# ...                       ...                          ...
# 1965                       na                           na
# 1964                       na                           na
# 1963                       na                           na
# 1962                       na                           na
# 1961                       na                           na
#
#                                        8                             9    ...  \
# DataSeries              Biscuits & Cookies              Cakes & Pastries  ...
# 2024                               122.251                       121.001  ...
# 2023                               120.025                       115.357  ...
# 2022                               112.422                       108.106  ...
# 2021                               104.667                       103.838  ...
# ...                                    ...                           ...  ...
# 1965                                    na                            na  ...
# 1964                                    na                            na  ...
# 1963                                    na                            na  ...
# 1962                                    na                            na  ...
# 1961                                    na                            na  ...
#
#                                    142               143  \
# DataSeries              Spirits & Wine              Beer
# 2024                           102.159            98.602
# 2023                             100.9            102.23
# 2022                            97.458            97.748
# 2021                             97.84             95.32
# ...                                ...               ...
# 1965                                na                na
# 1964                                na                na
# 1963                                na                na
# 1962                                na                na
# 1961                                na                na
#
#                                144                       145  \
# DataSeries              Cigarettes          Personal Effects
# 2024                       118.196                    97.756
# 2023                       113.712                    97.317
# 2022                       101.195                     97.16
# 2021                        99.879                    96.432
# ...                            ...                       ...
# 1965                            na                        na
# 1964                            na                        na
# 1963                            na                        na
# 1962                            na                        na
# 1961                            na                        na
#
#                                         146  \
# DataSeries              Jewellery & Watches
# 2024                                 97.368
# 2023                                 96.097
# 2022                                 94.082
# 2021                                 97.139
# ...                                     ...
# 1965                                     na
# 1964                                     na
# 1963                                     na
# 1962                                     na
# 1961                                     na
#
#                                            147                      148  \
# DataSeries              Other Personal Effects          Social Services
# 2024                                    97.953                   94.506
# 2023                                    97.939                   93.845
# 2022                                    98.728                   94.962
# 2021                                    96.071                   95.309
# ...                                        ...                      ...
# 1965                                        na                       na
# 1964                                        na                       na
# 1963                                        na                       na
# 1962                                        na                       na
# 1961                                        na                       na
#
#                                              149  \
# DataSeries          Other Miscellaneous Services
# 2024                                        96.5
# 2023                                      95.154
# 2022                                      95.772
# 2021                                      100.02
# ...                                          ...
# 1965                                          na
# 1964                                          na
# 1963                                          na
# 1962                                          na
# 1961                                          na
#
#                                                           150  \
# DataSeries  All Items Less Imputed Rentals On Owner-Occupi...
# 2024                                                  116.521
# 2023                                                  113.973
# 2022                                                  108.705
# 2021                                                  102.128
# ...                                                       ...
# 1965                                                       na
# 1964                                                       na
# 1963                                                       na
# 1962                                                       na
# 1961                                                       na
#
#                                      151
# DataSeries  All Items Less Accommodation
# 2024                             116.845
# 2023                             114.334
# 2022                             108.992
# 2021                             102.197
# ...                                  ...
# 1965                                  na
# 1964                                  na
# 1963                                  na
# 1962                                  na
# 1961                                  na
#
# [65 rows x 152 columns]

# %%
df2 = df.T[0]
df2 = df2.reset_index(drop=False)
df2 = df2.drop(0, axis=0)
df2.columns = ["Year", "CPI"]

# %%
df2
# Out:
#     Year      CPI
# 1   2024  116.283
# 2   2023  113.595
# 3   2022   108.37
# 4   2021  102.119
# 5   2020   99.818
# ..   ...      ...
# 60  1965   25.513
# 61  1964   25.448
# 62  1963   25.033
# 63  1962   24.513
# 64  1961   24.401
#
# [64 rows x 2 columns]

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# Year    0
# CPI     0
# dtype: int64

# %%
df2['Year'] = pd.to_datetime(df2['Year'], format='%Y')
df2['CPI'] = pd.to_numeric(df2['CPI'], errors='coerce')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 1 to 64
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    64 non-null     datetime64[ns]
#  1   CPI     64 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 1.1 KB
